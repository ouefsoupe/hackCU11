# %%
# import torch
# import torch.nn as nn
# import torch.optim as optim
# from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt

# %%
def get_coordinate(x: int, y: int): #returns None if invalid coordinate
  x -= 1
  if (y == 0):
    if (x % 2 == 1):
      y += 1
  elif (y == 1): return None
  elif (y >= 33):
    if (y % 2 == 1) or (x % 2 == 0): return None
  else:
    if (x % 2 == 0):
        if (y % 2 == 0): return None
        if (y % 4 == 0) and (x % 4 == 0): return None
        if (y % 4 != 0) and (x % 4 != 0): return None
    elif (y % 2 == 1): return None
  return (x, y)

def is_valid(x: int, y: int):
    if (y == 0): return True
    if (x % 2 == 1): return True
    if (y % 2 == 0):
        return (x % 4 == 0)
    else: return (x % 4 != 0)

# %%
valid = []
invalid = []
for x in range(0, 36):
  for y in range(0, 36):
      if (is_valid(x, y)): valid.append((x, y))

xv, yv = [], []
xi, yi = [], []
for c in valid:
  xv.append(c[0])
  yv.append(c[1])
for c in invalid:
  xi.append(c[0])
  yi.append(c[1])

plt.plot(xv, yv, 'o')
plt.plot(xi, yi, 'o', color='red')
plt.show()

# %%
coords = []
coords_screw = []
for x in range(1, 36):
  for y in range(0, 36):
    c = get_coordinate(x, y)
    if (c != None): 
        if (x % 2 == 1): coords_screw.append(c)
        else: coords.append(c)

x_coords, y_coords = [], []
x_coords_screw, y_coords_screw = [], []
for c in coords:
  x_coords.append(c[0])
  y_coords.append(c[1])
for c in coords_screw:
  x_coords_screw.append(c[0])
  y_coords_screw.append(c[1])


plt.plot(x_coords, y_coords, 'o')
plt.plot(x_coords_screw, y_coords_screw, 'o', color='red')

plt.show()
